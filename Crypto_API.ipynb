# %%
import pandas as pd
from dotenv import load_dotenv

# %%
API_Key = 'A9HTPYBVOW6MI2HN'

# %%
#Crypto API
daily_df = pd.read_csv(f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_WEEKLY&symbol=BTC&market=CNY&apikey={API_Key}&datatype=csv')

# %%
daily_df
# Out:
#       timestamp     open (CNY)     high (CNY)      low (CNY)    close (CNY)  \
# 0    2022-02-17  266334.176180  283419.566480  263148.006592  278455.857648
# 1    2022-02-13  268406.525884  290193.557200  263751.497220  266334.239512
# 2    2022-02-06  239912.699100  270148.979200  229578.500000  268406.525884
# 3    2022-01-30  229543.984060  246488.017336  208471.021044  239912.762432
# 4    2022-01-23  272781.437112  275525.866000  215379.465600  229543.984060
# ..          ...            ...            ...            ...            ...
# 138  2019-06-30   69069.562540   88474.804000   66657.563320   68741.186120
# 139  2019-06-23   56701.139600   72151.867648   56682.140000   69070.322524
# 140  2019-06-16   48306.926324   59107.755600   47568.665200   56703.229556
# 141  2019-06-09   55263.503200   55738.176540   47148.014056   48310.472916
# 142  2019-06-02   54544.938328   57469.103432   50697.266000   55263.376536
#
# ...
